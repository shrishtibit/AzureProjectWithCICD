# %% [markdown]
# ## Dynamic Data Reading

# %% [markdown]
# **Parameters**

# %%
dbutils.widgets.text("source_container", "")
dbutils.widgets.text("sink_container", "")
dbutils.widgets.text("folder", "")

# %% [markdown]
# **Fetching Parameters**

# %%
source_container = dbutils.widgets.get("source_container")
sink_container = dbutils.widgets.get("sink_container")
folder = dbutils.widgets.get("folder")

# %% [markdown]
# **Parameterizing code**

# %%
df = spark.read.format("parquet")\
                      .load(f"abfss://{source_container}@olympicsprojshrishti.dfs.core.windows.net/{folder}")

# %%
df.display()

# %%
df.write.format("delta")\
        .mode("append")\
        .option("path", f"abfss://{sink_container}@olympicsprojshrishti.dfs.core.windows.net/{folder}")\
        .saveAsTable(f"olympics.{sink_container}.{folder}")

# %%
# To drop the metadata for subsequent runs
# DROP TABLE olympics.silver.coaches
